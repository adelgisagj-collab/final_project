# %% [markdown]
# This scrip is made to create a df_lookup that will be used as index to complete the missing values in the df (based on users.csv table of bigquery-public-data.thelook_ecommerce) to create a df_final to be saved as users_clean.csv

# %%
#library import
import pandas as pd
import requests
import time
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#upload and dataset visualization
df = pd.read_csv("users_cleaned.csv")
df.head()
# Out:
#    user_id   first_name  last_name                         email  age gender  \
# 0    75822        Janet       Boyd         janetboyd@example.com   43      F
# 1    36479  Christopher      Hardy  christopherhardy@example.org   33      M
# 2    35495         Eric    Shelton       ericshelton@example.com   41      M
# 3    97574       Audrey  Patterson   audreypatterson@example.com   57      F
# 4    82326         Lisa  Alexander     lisaalexander@example.org   59      F
#
#   state               street_address postal_code city country traffic_source  \
# 0  Acre          91843 Mcdaniel Ways   69980-000  NaN  Brasil       Facebook
# 1  Acre        69363 Myers Junctions   69980-000  NaN  Brasil         Search
# 2  Acre                 178 Paul Row   69980-000  NaN  Brasil         Search
# 3  Acre           608 Rachel Orchard   69980-000  NaN  Brasil         Search
# 4  Acre  189 Rebecca Ferry Suite 092   69980-000  NaN  Brasil         Search
#
#             created_at                         user_geom
# 0  2019-06-08 11:39:00  POINT(-72.87094866 -8.065346116)
# 1  2019-07-18 01:03:00  POINT(-72.87094866 -8.065346116)
# 2  2019-10-01 02:06:00  POINT(-72.87094866 -8.065346116)
# 3  2024-02-12 15:00:00  POINT(-72.87094866 -8.065346116)
# 4  2025-05-14 09:21:00  POINT(-72.87094866 -8.065346116)

# %%
#puntual data error fetching and cleaning
df.loc[(df['postal_code'] == '29142') & (df['country'] == 'Brasil'), ['city', 'postal_code']] = ['Cariacica', '29142-000']

# %%
#tuplas compose dictionary creation for problematic and dupolicate postal_code values
fix_map_country = {
    ("29140", "France"): "Rosporden",
    ("29140", "Spain"): "Málaga",
    ("38300", "France"): "Bourgoin-Jallieu",
    ("38300", "Spain"): "La Orotava",
    ("13090", "France"): "Aix-en-Provence",
    ("13090", "United States"): "Liverpool",
    ("3581", "Spain"): "L'Alfàs del Pi",
    ("30045", "China"): "Xiqing",
    ("300384", "China"): "Xiqing",
    ("46394", "Spain"):  "Riba-roja de Túria"
    }

# %%
#dictionary application
df["city"] = df.apply(
    lambda row: fix_map_country.get((row["postal_code"], row["country"]), row["city"]),
    axis=1
)

# %%
#checking for NaN values for postal codes
missing_codes = df[df['city'].isnull()]['postal_code'].unique()
print(missing_codes)
# Out:
# ['69980-000' '57360-000' '68924-000' '69630-000' '69880-000' '69600-000'
#  '69830-000' '69460-000' '69800-000' '69280-000' '69435-000' '69250-000'
#  '69735-000' '69200-000' '69230-000' '69190-000' '41130' '50197' '50191'
#  '50059' '50016' '47240-000' '47350-000' '48760-000' '44330-000'
#  '48790-000' '48475-000' '38434' '25191' '62150-000' '63610-000'
#  '63560-000' '63540-000' '46988' '28946' '28947' '28909' '28524' '19803'
#  '72016-190' '72110-600' '72025-065' '32060' '33579' '34482' '34476'
#  '32092' '32826' '32828' '32940' '33437' '15174' '30102' '30028' '30093'
#  '30044' '30016' '30045' '75370-000' '73900-000' '631-830' '631-820'
#  '631-810' '630-850' '630-857' '630-856' '630-040' '630-520' '630-492'
#  '630-490' '630-500' '642-370' '641-465' '641-860' '642-315' '641-920'
#  '70706' '65380-000' '65393-000' '65365-000' '65278-000' '65725-000'
#  '65415-000' '65690-000' '65530-000' '78850-000' '48044' '39260-000'
#  '88201' '12065' '33129' '27537' '84600-000' '68250-000' '68230-000'
#  '68330-000' '68300-000' '68890-000' '68473-000' '68540-000' '68695-000'
#  '68660-000' '68650-000' '68620-000' '68617-000' '17015' '18302'
#  '56380-000' '56180-000' '56460-000' '55730-000' '55920-000' '30162'
#  '76868-000' '76980-000' '79706' '77379' '77389' '22602' '23236' '22407'
#  '22406' '22556' '22408' '20112' '20171' '23188' '23693' '98926']

# %%
#looking for city by postal code and country using OpenStreetMap API function definition
def get_city_osm(postal_code, country):
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "postalcode": postal_code,
        "country": country,
        "format": "json",
        "addressdetails": 1,
        "limit": 1
    }

    headers = {
        "User-Agent": "AlessandroPostalLookup/1.0"
    }

    try:
        r = requests.get(url, params=params, headers=headers, timeout=10)
        if r.status_code == 200 and len(r.json()) > 0:
            addr = r.json()[0]["address"]
            return (
                addr.get("city") or
                addr.get("town") or
                addr.get("village") or
                addr.get("municipality")
            )
    except:
        return None

    return None

# %%
#looking for city by postal code and country using OpenStreetMap API
results = []

missing_rows = df[df['city'].isnull()][['postal_code', 'country']].drop_duplicates()

for idx, row in missing_rows.iterrows():
    pc = row['postal_code']
    country = row['country']

    city = get_city_osm(pc, country)

    results.append({
        "postal_code": pc,
        "city": city
    })

    print(f"{pc} ({country}) → {city}")

    time.sleep(1)  #respecting OSM rate limit
# Out:
# 69980-000 (Brasil) → Cruzeiro do Sul
# 57360-000 (Brasil) → Girau do Ponciano
# 68924-000 (Brasil) → Vitória do Jari
# 69630-000 (Brasil) → Benjamin Constant
# 69880-000 (Brasil) → Eirunepé
# 69600-000 (Brasil) → São Paulo de Olivença
# 69830-000 (Brasil) → Lábrea
# 69460-000 (Brasil) → Coari
# 69800-000 (Brasil) → Humaitá
# 69280-000 (Brasil) → None
# 69435-000 (Brasil) → None
# 69250-000 (Brasil) → Careiro
# 69735-000 (Brasil) → Presidente Figueiredo
# 69200-000 (Brasil) → Borba
# 69230-000 (Brasil) → None
# 69190-000 (Brasil) → Jacareacanga
# 41130 (Spain) → La Puebla del Río
# 50197 (Spain) → Zaragoza
# 50191 (Spain) → Zaragoza
# 50059 (Spain) → Zaragoza
# 50016 (Spain) → Zaragoza
# 47240-000 (Brasil) → None
# 47350-000 (Brasil) → Sento Sé
# 48760-000 (Brasil) → Araci
# 44330-000 (Brasil) → São Gonçalo dos Campos
# 48790-000 (Brasil) → Tucano
# 48475-000 (Brasil) → Itapicuru
# 38434 (Spain) → Icod de los Vinos
# 25191 (Spain) → Lleida
# 62150-000 (Brasil) → None
# 63610-000 (Brasil) → Mombaça
# 63560-000 (Brasil) → Acopiara
# 63540-000 (Brasil) → Várzea Alegre
# 46988 (Spain) → Paterna
# 28946 (Spain) → Fuenlabrada
# 28947 (Spain) → Fuenlabrada
# 28909 (Spain) → Getafe
# 28524 (Spain) → Rivas-Vaciamadrid
# 19803 (United States) → None
# 72016-190 (Brasil) → Taguatinga
# 72110-600 (Brasil) → Vicente Pires
# 72025-065 (Brasil) → Taguatinga
# 32060 (United States) → None
# 33579 (United States) → None
# 34482 (United States) → None
# 34476 (United States) → None
# 32092 (United States) → None
# 32826 (United States) → University
# 32828 (United States) → None
# 32940 (United States) → None
# 33437 (United States) → None
# 15174 (Spain) → Culleredo
# 30102 (United States) → None
# 30028 (United States) → None
# 30093 (United States) → None
# 30044 (United States) → None
# 30016 (United States) → None
# 30045 (United States) → Lawrenceville
# 75370-000 (Brasil) → Goianira
# 73900-000 (Brasil) → Posse
# 631-830 (South Korea) → None
# 631-820 (South Korea) → None
# 631-810 (South Korea) → None
# 630-850 (South Korea) → None
# 630-857 (South Korea) → None
# 630-856 (South Korea) → None
# 630-040 (South Korea) → None
# 630-520 (South Korea) → None
# 630-492 (South Korea) → None
# 630-490 (South Korea) → None
# 630-500 (South Korea) → None
# 642-370 (South Korea) → None
# 641-465 (South Korea) → None
# 641-860 (South Korea) → None
# 642-315 (South Korea) → None
# 641-920 (South Korea) → None
# 70706 (United States) → None
# 65380-000 (Brasil) → Alto Alegre do Pindaré
# 65393-000 (Brasil) → Buriticupu
# 65365-000 (Brasil) → Zé Doca
# 65278-000 (Brasil) → Turiaçu
# 65725-000 (Brasil) → Pedreiras
# 65415-000 (Brasil) → Coroatá
# 65690-000 (Brasil) → Colinas
# 65530-000 (Brasil) → Urbano Santos
# 78850-000 (Brasil) → Primavera do Leste
# 48044 (United States) → Macomb Township
# 39260-000 (Brasil) → Várzea da Palma
# 88201 (United States) → Roswell
# 12065 (United States) → Town of Clifton Park
# 33129 (Germany) → Delbrück
# 27537 (United States) → Henderson
# 84600-000 (Brasil) → União da Vitória
# 68250-000 (Brasil) → Óbidos
# 68230-000 (Brasil) → Almeirim
# 68330-000 (Brasil) → None
# 68300-000 (Brasil) → Gurupá
# 68890-000 (Brasil) → Afuá
# 68473-000 (Brasil) → Novo Repartimento
# 68540-000 (Brasil) → Conceição do Araguaia
# 68695-000 (Brasil) → Tailândia
# 68660-000 (Brasil) → São Miguel do Guamá
# 68650-000 (Brasil) → Capitão Poço
# 68620-000 (Brasil) → Viseu
# 68617-000 (Brasil) → None
# 17015 (United States) → Dickinson Township
# 18302 (United States) → Middle Smithfield Township
# 56380-000 (Brasil) → Santa Maria da Boa Vista
# 56180-000 (Brasil) → Cabrobó
# 56460-000 (Brasil) → Petrolândia
# 55730-000 (Brasil) → Bom Jardim
# 55920-000 (Brasil) → Itambé
# 30162 (Spain) → Murcia
# 76868-000 (Brasil) → Machadinho D'Oeste
# 76980-000 (Brasil) → Vilhena
# 79706 (United States) → None
# 77379 (United States) → None
# 77389 (United States) → None
# 22602 (United States) → Winchester
# 23236 (United States) → None
# 22407 (United States) → None
# 22406 (United States) → None
# 22556 (United States) → None
# 22408 (United States) → None
# 20112 (United States) → None
# 20171 (United States) → None
# 23188 (United States) → None
# 23693 (United States) → None
# 98926 (United States) → Ellensburg

# %%
#sending results to a dataframe
df_lookup = pd.DataFrame(results)

# %%
#merging the lookup dataframe with the original dataframe
df_lookup = df_lookup.merge(
    df[['postal_code', 'country', 'state']].drop_duplicates(),
    on='postal_code',
    how='left'
)

# %%
print(df_lookup)
# Out:
#     postal_code                        city        country  \
# 0     69980-000             Cruzeiro do Sul         Brasil
# 1     57360-000           Girau do Ponciano         Brasil
# 2     68924-000             Vitória do Jari         Brasil
# 3     69630-000           Benjamin Constant         Brasil
# 4     69880-000                    Eirunepé         Brasil
# 5     69600-000       São Paulo de Olivença         Brasil
# 6     69830-000                      Lábrea         Brasil
# 7     69460-000                       Coari         Brasil
# 8     69800-000                     Humaitá         Brasil
# 9     69280-000                        None         Brasil
# 10    69435-000                        None         Brasil
# 11    69250-000                     Careiro         Brasil
# 12    69735-000       Presidente Figueiredo         Brasil
# 13    69200-000                       Borba         Brasil
# 14    69230-000                        None         Brasil
# 15    69190-000                Jacareacanga         Brasil
# 16        41130           La Puebla del Río          Spain
# 17        50197                    Zaragoza          Spain
# 18        50191                    Zaragoza          Spain
# 19        50059                    Zaragoza          Spain
# 20        50016                    Zaragoza          Spain
# 21    47240-000                        None         Brasil
# 22    47350-000                    Sento Sé         Brasil
# 23    48760-000                       Araci         Brasil
# 24    44330-000      São Gonçalo dos Campos         Brasil
# 25    48790-000                      Tucano         Brasil
# 26    48475-000                   Itapicuru         Brasil
# 27        38434           Icod de los Vinos          Spain
# 28        25191                      Lleida          Spain
# 29    62150-000                        None         Brasil
# 30    63610-000                     Mombaça         Brasil
# 31    63560-000                    Acopiara         Brasil
# 32    63540-000               Várzea Alegre         Brasil
# 33        46394                        None          Spain
# 34        46988                     Paterna          Spain
# 35        28946                 Fuenlabrada          Spain
# 36        28947                 Fuenlabrada          Spain
# 37        28909                      Getafe          Spain
# 38        28524           Rivas-Vaciamadrid          Spain
# 39        19803                        None  United States
# 40    72016-190                  Taguatinga         Brasil
# 41    72110-600               Vicente Pires         Brasil
# 42    72025-065                  Taguatinga         Brasil
# 43        32060                        None  United States
# 44        33579                        None  United States
# 45        34482                        None  United States
# 46        34476                        None  United States
# 47        32092                        None  United States
# 48        32826                  University  United States
# 49        32828                        None  United States
# 50        32940                        None  United States
# 51        33437                        None  United States
# 52        15174                   Culleredo          Spain
# 53        30102                        None  United States
# 54        30028                        None  United States
# 55        30093                        None  United States
# 56        30044                        None  United States
# 57        30016                        None  United States
# 58        30045               Lawrenceville  United States
# 59        30045               Lawrenceville          China
# 60    75370-000                    Goianira         Brasil
# 61    73900-000                       Posse         Brasil
# 62      631-830                        None    South Korea
# 63      631-820                        None    South Korea
# 64      631-810                        None    South Korea
# 65      630-850                        None    South Korea
# 66      630-857                        None    South Korea
# 67      630-856                        None    South Korea
# 68      630-040                        None    South Korea
# 69      630-520                        None    South Korea
# 70      630-492                        None    South Korea
# 71      630-490                        None    South Korea
# 72      630-500                        None    South Korea
# 73      642-370                        None    South Korea
# 74      641-465                        None    South Korea
# 75      641-860                        None    South Korea
# 76      642-315                        None    South Korea
# 77      641-920                        None    South Korea
# 78        70706                        None  United States
# 79    65380-000      Alto Alegre do Pindaré         Brasil
# 80    65393-000                  Buriticupu         Brasil
# 81    65365-000                     Zé Doca         Brasil
# 82    65278-000                     Turiaçu         Brasil
# 83    65725-000                   Pedreiras         Brasil
# 84    65415-000                     Coroatá         Brasil
# 85    65690-000                     Colinas         Brasil
# 86    65530-000               Urbano Santos         Brasil
# 87    78850-000          Primavera do Leste         Brasil
# 88        48044             Macomb Township  United States
# 89    39260-000             Várzea da Palma         Brasil
# 90        88201                     Roswell  United States
# 91        12065        Town of Clifton Park  United States
# 92        33129                    Delbrück        Germany
# 93        27537                   Henderson  United States
# 94    84600-000            União da Vitória         Brasil
# 95    68250-000                      Óbidos         Brasil
# 96    68230-000                    Almeirim         Brasil
# 97    68330-000                        None         Brasil
# 98    68300-000                      Gurupá         Brasil
# 99    68890-000                        Afuá         Brasil
# 100   68473-000           Novo Repartimento         Brasil
# 101   68540-000       Conceição do Araguaia         Brasil
# 102   68695-000                   Tailândia         Brasil
# 103   68660-000         São Miguel do Guamá         Brasil
# 104   68650-000                Capitão Poço         Brasil
# 105   68620-000                       Viseu         Brasil
# 106   68617-000                        None         Brasil
# 107       17015          Dickinson Township  United States
# 108       18302  Middle Smithfield Township  United States
# 109   56380-000    Santa Maria da Boa Vista         Brasil
# 110   56180-000                     Cabrobó         Brasil
# 111   56460-000                 Petrolândia         Brasil
# 112   55730-000                  Bom Jardim         Brasil
# 113   55920-000                      Itambé         Brasil
# 114       30162                      Murcia          Spain
# 115   76868-000          Machadinho D'Oeste         Brasil
# 116   76980-000                     Vilhena         Brasil
# 117       79706                        None  United States
# 118       77379                        None  United States
# 119       77389                        None  United States
# 120       22602                  Winchester  United States
# 121       23236                        None  United States
# 122       22407                        None  United States
# 123       22406                        None  United States
# 124       22556                        None  United States
# 125       22408                        None  United States
# 126       20112                        None  United States
# 127       20171                        None  United States
# 128       23188                        None  United States
# 129       23693                        None  United States
# 130       98926                  Ellensburg  United States
#
#                     state
# 0                    Acre
# 1                 Alagoas
# 2                   Amapá
# 3                Amazonas
# 4                Amazonas
# 5                Amazonas
# 6                Amazonas
# 7                Amazonas
# 8                Amazonas
# 9                Amazonas
# 10               Amazonas
# 11               Amazonas
# 12               Amazonas
# 13               Amazonas
# 14               Amazonas
# 15               Amazonas
# 16              Andalucía
# 17                 Aragón
# 18                 Aragón
# 19                 Aragón
# 20                 Aragón
# 21                  Bahia
# 22                  Bahia
# 23                  Bahia
# 24                  Bahia
# 25                  Bahia
# 26                  Bahia
# 27               Canarias
# 28               Cataluña
# 29                  Ceará
# 30                  Ceará
# 31                  Ceará
# 32                  Ceará
# 33   Comunidad Valenciana
# 34   Comunidad Valenciana
# 35    Comunidad de Madrid
# 36    Comunidad de Madrid
# 37    Comunidad de Madrid
# 38    Comunidad de Madrid
# 39               Delaware
# 40       Distrito Federal
# 41       Distrito Federal
# 42       Distrito Federal
# 43                Florida
# 44                Florida
# 45                Florida
# 46                Florida
# 47                Florida
# 48                Florida
# 49                Florida
# 50                Florida
# 51                Florida
# 52                Galicia
# 53                Georgia
# 54                Georgia
# 55                Georgia
# 56                Georgia
# 57                Georgia
# 58                Georgia
# 59                 Shanxi
# 60                  Goiás
# 61                  Goiás
# 62       Gyeongsangnam-do
# 63       Gyeongsangnam-do
# 64       Gyeongsangnam-do
# 65       Gyeongsangnam-do
# 66       Gyeongsangnam-do
# 67       Gyeongsangnam-do
# 68       Gyeongsangnam-do
# 69       Gyeongsangnam-do
# 70       Gyeongsangnam-do
# 71       Gyeongsangnam-do
# 72       Gyeongsangnam-do
# 73       Gyeongsangnam-do
# 74       Gyeongsangnam-do
# 75       Gyeongsangnam-do
# 76       Gyeongsangnam-do
# 77       Gyeongsangnam-do
# 78              Louisiana
# 79               Maranhão
# 80               Maranhão
# 81               Maranhão
# 82               Maranhão
# 83               Maranhão
# 84               Maranhão
# 85               Maranhão
# 86               Maranhão
# 87            Mato Grosso
# 88               Michigan
# 89           Minas Gerais
# 90             New Mexico
# 91               New York
# 92    Nordrhein-Westfalen
# 93         North Carolina
# 94                 Paraná
# 95                   Pará
# 96                   Pará
# 97                   Pará
# 98                   Pará
# 99                   Pará
# 100                  Pará
# 101                  Pará
# 102                  Pará
# 103                  Pará
# 104                  Pará
# 105                  Pará
# 106                  Pará
# 107          Pennsylvania
# 108          Pennsylvania
# 109            Pernambuco
# 110            Pernambuco
# 111            Pernambuco
# 112            Pernambuco
# 113            Pernambuco
# 114      Región de Murcia
# 115              Rondônia
# 116              Rondônia
# 117                 Texas
# 118                 Texas
# 119                 Texas
# 120              Virginia
# 121              Virginia
# 122              Virginia
# 123              Virginia
# 124              Virginia
# 125              Virginia
# 126              Virginia
# 127              Virginia
# 128              Virginia
# 129              Virginia
# 130            Washington

# %%
#looking for missing info
missing_info = df_lookup[df_lookup['city'].isnull()].copy()
print(f"{missing_info}\nLength: {len(missing_info)}")
# Out:
#     postal_code  city        country             state
# 9     69280-000  None         Brasil          Amazonas
# 10    69435-000  None         Brasil          Amazonas
# 14    69230-000  None         Brasil          Amazonas
# 21    47240-000  None         Brasil             Bahia
# 29    62150-000  None         Brasil             Ceará
# 38        19803  None  United States          Delaware
# 42        32060  None  United States           Florida
# 43        33579  None  United States           Florida
# 44        34482  None  United States           Florida
# 45        34476  None  United States           Florida
# 46        32092  None  United States           Florida
# 48        32828  None  United States           Florida
# 49        32940  None  United States           Florida
# 50        33437  None  United States           Florida
# 52        30102  None  United States           Georgia
# 53        30028  None  United States           Georgia
# 54        30093  None  United States           Georgia
# 55        30044  None  United States           Georgia
# 56        30016  None  United States           Georgia
# 61      631-830  None    South Korea  Gyeongsangnam-do
# 62      631-820  None    South Korea  Gyeongsangnam-do
# 63      631-810  None    South Korea  Gyeongsangnam-do
# 64      630-850  None    South Korea  Gyeongsangnam-do
# 65      630-857  None    South Korea  Gyeongsangnam-do
# 66      630-856  None    South Korea  Gyeongsangnam-do
# 67      630-040  None    South Korea  Gyeongsangnam-do
# 68      630-520  None    South Korea  Gyeongsangnam-do
# 69      630-492  None    South Korea  Gyeongsangnam-do
# 70      630-490  None    South Korea  Gyeongsangnam-do
# 71      630-500  None    South Korea  Gyeongsangnam-do
# 72      642-370  None    South Korea  Gyeongsangnam-do
# 73      641-465  None    South Korea  Gyeongsangnam-do
# 74      641-860  None    South Korea  Gyeongsangnam-do
# 75      642-315  None    South Korea  Gyeongsangnam-do
# 76      641-920  None    South Korea  Gyeongsangnam-do
# 77        70706  None  United States         Louisiana
# 96    68330-000  None         Brasil              Pará
# 105   68617-000  None         Brasil              Pará
# 116       79706  None  United States             Texas
# 117       77379  None  United States             Texas
# 118       77389  None  United States             Texas
# 120       23236  None  United States          Virginia
# 121       22407  None  United States          Virginia
# 122       22406  None  United States          Virginia
# 123       22556  None  United States          Virginia
# 124       22408  None  United States          Virginia
# 125       20112  None  United States          Virginia
# 126       20171  None  United States          Virginia
# 127       23188  None  United States          Virginia
# 128       23693  None  United States          Virginia
# Length: 50

# %%
#dataframe filtering
to_retry = missing_info[
    missing_info['country'].isin(['United States', 'Brasil', 'Brazil'])
]['postal_code']

# %%
#function for city extraction from brasilapi
def get_city_br(postal_code):
    pc = str(postal_code).replace("-", "")
    url = f"https://brasilapi.com.br/api/cep/v1/{pc}"
    try:
        r = requests.get(url, timeout=5)
        if r.status_code == 200:
            return r.json().get("city")
    except:
        return None
    return None

#function for city extraction from zippopotam
def get_city_us(postal_code):
    url = f"https://api.zippopotam.us/us/{postal_code}"
    try:
        r = requests.get(url, timeout=5)
        if r.status_code == 200:
            return r.json()["places"][0]["place name"]
    except:
        return None
    return None

# %%
#functions application
retry_results = []

for pc in to_retry:
    country = missing_info.loc[missing_info['postal_code'] == pc, 'country'].iloc[0]

    if country in ['Brasil', 'Brazil']:
        city = get_city_br(pc)
    elif country == 'United States':
        city = get_city_us(pc)
    else:
        city = None

    retry_results.append({
        "postal_code": pc,
        "city_retry": city
    })

    print(f"{pc} ({country}) → {city}")
    time.sleep(0.2)
# Out:
# 69280-000 (Brasil) → Manicoré
# 69435-000 (Brasil) → Manaquiri
# 69230-000 (Brasil) → Nova Olinda do Norte
# 47240-000 (Brasil) → Pilão Arcado
# 62150-000 (Brasil) → Santana do Acaraú
# 19803 (United States) → Wilmington
# 32060 (United States) → Live Oak
# 33579 (United States) → Riverview
# 34482 (United States) → Ocala
# 34476 (United States) → Ocala
# 32092 (United States) → Saint Augustine
# 32828 (United States) → Orlando
# 32940 (United States) → Melbourne
# 33437 (United States) → Boynton Beach
# 30102 (United States) → Acworth
# 30028 (United States) → Cumming
# 30093 (United States) → Norcross
# 30044 (United States) → Lawrenceville
# 30016 (United States) → Covington
# 70706 (United States) → Denham Springs
# 68330-000 (Brasil) → Porto de Moz
# 68617-000 (Brasil) → Cachoeira do Piriá
# 79706 (United States) → Midland
# 77379 (United States) → Spring
# 77389 (United States) → Spring
# 23236 (United States) → Richmond
# 22407 (United States) → Fredericksburg
# 22406 (United States) → Fredericksburg
# 22556 (United States) → Stafford
# 22408 (United States) → Fredericksburg
# 20112 (United States) → Manassas
# 20171 (United States) → Herndon
# 23188 (United States) → Williamsburg
# 23693 (United States) → Yorktown

# %%
#df_lookup data enrichment
df_retry = pd.DataFrame(retry_results)
df_lookup = df_lookup.merge(df_retry, on='postal_code', how='left')
df_lookup['city'] = df_lookup['city'].fillna(df_lookup['city_retry'])
df_lookup = df_lookup.drop(columns=['city_retry'])

# %%
#looking for missing city info
missing_info2 = df_lookup[df_lookup['city'].isnull()].copy()
print(missing_info2)
# Out:
#    postal_code city      country             state
# 61     631-830  NaN  South Korea  Gyeongsangnam-do
# 62     631-820  NaN  South Korea  Gyeongsangnam-do
# 63     631-810  NaN  South Korea  Gyeongsangnam-do
# 64     630-850  NaN  South Korea  Gyeongsangnam-do
# 65     630-857  NaN  South Korea  Gyeongsangnam-do
# 66     630-856  NaN  South Korea  Gyeongsangnam-do
# 67     630-040  NaN  South Korea  Gyeongsangnam-do
# 68     630-520  NaN  South Korea  Gyeongsangnam-do
# 69     630-492  NaN  South Korea  Gyeongsangnam-do
# 70     630-490  NaN  South Korea  Gyeongsangnam-do
# 71     630-500  NaN  South Korea  Gyeongsangnam-do
# 72     642-370  NaN  South Korea  Gyeongsangnam-do
# 73     641-465  NaN  South Korea  Gyeongsangnam-do
# 74     641-860  NaN  South Korea  Gyeongsangnam-do
# 75     642-315  NaN  South Korea  Gyeongsangnam-do
# 76     641-920  NaN  South Korea  Gyeongsangnam-do

# %%
# dictionary creatoin for missing values
korea_map = {
    "631-830": "Changwon",
    "631-820": "Changwon",
    "631-810": "Changwon",
    "630-850": "Changwon",
    "630-857": "Changwon",
    "630-856": "Changwon",
    "630-040": "Changwon",
    "630-520": "Changwon",
    "631-840": "Changwon",
    "630-490": "Changwon",
    "641-870": "Changwon",
    "630-500": "Changwon",
    "642-370": "Changwon",
    "641-465": "Changwon",
    "641-860": "Changwon",
    "642-315": "Changwon",
    "641-920": "Changwon",
    "630-492": "Changwon"
}
#df_lookup data enrichment
df_lookup['city'] = df_lookup.apply(
    lambda row: korea_map.get(row['postal_code'], row['city'])
    if row['country'] == 'South Korea' else row['city'],
    axis=1
)

# %%
#looking for missing values
missing_info3 = df_lookup[df_lookup['city'].isnull()].copy()
print(missing_info3)
# Out:
# Empty DataFrame
# Columns: [postal_code, city, country, state]
# Index: []

# %%
print(df_lookup)
# Out:
#     postal_code                        city        country  \
# 0     69980-000             Cruzeiro do Sul         Brasil
# 1     57360-000           Girau do Ponciano         Brasil
# 2     68924-000             Vitória do Jari         Brasil
# 3     69630-000           Benjamin Constant         Brasil
# 4     69880-000                    Eirunepé         Brasil
# 5     69600-000       São Paulo de Olivença         Brasil
# 6     69830-000                      Lábrea         Brasil
# 7     69460-000                       Coari         Brasil
# 8     69800-000                     Humaitá         Brasil
# 9     69280-000                    Manicoré         Brasil
# 10    69435-000                   Manaquiri         Brasil
# 11    69250-000                     Careiro         Brasil
# 12    69735-000       Presidente Figueiredo         Brasil
# 13    69200-000                       Borba         Brasil
# 14    69230-000        Nova Olinda do Norte         Brasil
# 15    69190-000                Jacareacanga         Brasil
# 16        41130           La Puebla del Río          Spain
# 17        50197                    Zaragoza          Spain
# 18        50191                    Zaragoza          Spain
# 19        50059                    Zaragoza          Spain
# 20        50016                    Zaragoza          Spain
# 21    47240-000                Pilão Arcado         Brasil
# 22    47350-000                    Sento Sé         Brasil
# 23    48760-000                       Araci         Brasil
# 24    44330-000      São Gonçalo dos Campos         Brasil
# 25    48790-000                      Tucano         Brasil
# 26    48475-000                   Itapicuru         Brasil
# 27        38434           Icod de los Vinos          Spain
# 28        25191                      Lleida          Spain
# 29    62150-000           Santana do Acaraú         Brasil
# 30    63610-000                     Mombaça         Brasil
# 31    63560-000                    Acopiara         Brasil
# 32    63540-000               Várzea Alegre         Brasil
# 33        46988                     Paterna          Spain
# 34        28946                 Fuenlabrada          Spain
# 35        28947                 Fuenlabrada          Spain
# 36        28909                      Getafe          Spain
# 37        28524           Rivas-Vaciamadrid          Spain
# 38        19803                  Wilmington  United States
# 39    72016-190                  Taguatinga         Brasil
# 40    72110-600               Vicente Pires         Brasil
# 41    72025-065                  Taguatinga         Brasil
# 42        32060                    Live Oak  United States
# 43        33579                   Riverview  United States
# 44        34482                       Ocala  United States
# 45        34476                       Ocala  United States
# 46        32092             Saint Augustine  United States
# 47        32826                  University  United States
# 48        32828                     Orlando  United States
# 49        32940                   Melbourne  United States
# 50        33437               Boynton Beach  United States
# 51        15174                   Culleredo          Spain
# 52        30102                     Acworth  United States
# 53        30028                     Cumming  United States
# 54        30093                    Norcross  United States
# 55        30044               Lawrenceville  United States
# 56        30016                   Covington  United States
# 57        30045               Lawrenceville  United States
# 58        30045               Lawrenceville          China
# 59    75370-000                    Goianira         Brasil
# 60    73900-000                       Posse         Brasil
# 61      631-830                    Changwon    South Korea
# 62      631-820                    Changwon    South Korea
# 63      631-810                    Changwon    South Korea
# 64      630-850                    Changwon    South Korea
# 65      630-857                    Changwon    South Korea
# 66      630-856                    Changwon    South Korea
# 67      630-040                    Changwon    South Korea
# 68      630-520                    Changwon    South Korea
# 69      630-492                    Changwon    South Korea
# 70      630-490                    Changwon    South Korea
# 71      630-500                    Changwon    South Korea
# 72      642-370                    Changwon    South Korea
# 73      641-465                    Changwon    South Korea
# 74      641-860                    Changwon    South Korea
# 75      642-315                    Changwon    South Korea
# 76      641-920                    Changwon    South Korea
# 77        70706              Denham Springs  United States
# 78    65380-000      Alto Alegre do Pindaré         Brasil
# 79    65393-000                  Buriticupu         Brasil
# 80    65365-000                     Zé Doca         Brasil
# 81    65278-000                     Turiaçu         Brasil
# 82    65725-000                   Pedreiras         Brasil
# 83    65415-000                     Coroatá         Brasil
# 84    65690-000                     Colinas         Brasil
# 85    65530-000               Urbano Santos         Brasil
# 86    78850-000          Primavera do Leste         Brasil
# 87        48044             Macomb Township  United States
# 88    39260-000             Várzea da Palma         Brasil
# 89        88201                     Roswell  United States
# 90        12065        Town of Clifton Park  United States
# 91        33129                    Delbrück        Germany
# 92        27537                   Henderson  United States
# 93    84600-000            União da Vitória         Brasil
# 94    68250-000                      Óbidos         Brasil
# 95    68230-000                    Almeirim         Brasil
# 96    68330-000                Porto de Moz         Brasil
# 97    68300-000                      Gurupá         Brasil
# 98    68890-000                        Afuá         Brasil
# 99    68473-000           Novo Repartimento         Brasil
# 100   68540-000       Conceição do Araguaia         Brasil
# 101   68695-000                   Tailândia         Brasil
# 102   68660-000         São Miguel do Guamá         Brasil
# 103   68650-000                Capitão Poço         Brasil
# 104   68620-000                       Viseu         Brasil
# 105   68617-000          Cachoeira do Piriá         Brasil
# 106       17015          Dickinson Township  United States
# 107       18302  Middle Smithfield Township  United States
# 108   56380-000    Santa Maria da Boa Vista         Brasil
# 109   56180-000                     Cabrobó         Brasil
# 110   56460-000                 Petrolândia         Brasil
# 111   55730-000                  Bom Jardim         Brasil
# 112   55920-000                      Itambé         Brasil
# 113       30162                      Murcia          Spain
# 114   76868-000          Machadinho D'Oeste         Brasil
# 115   76980-000                     Vilhena         Brasil
# 116       79706                     Midland  United States
# 117       77379                      Spring  United States
# 118       77389                      Spring  United States
# 119       22602                  Winchester  United States
# 120       23236                    Richmond  United States
# 121       22407              Fredericksburg  United States
# 122       22406              Fredericksburg  United States
# 123       22556                    Stafford  United States
# 124       22408              Fredericksburg  United States
# 125       20112                    Manassas  United States
# 126       20171                     Herndon  United States
# 127       23188                Williamsburg  United States
# 128       23693                    Yorktown  United States
# 129       98926                  Ellensburg  United States
#
#                     state
# 0                    Acre
# 1                 Alagoas
# 2                   Amapá
# 3                Amazonas
# 4                Amazonas
# 5                Amazonas
# 6                Amazonas
# 7                Amazonas
# 8                Amazonas
# 9                Amazonas
# 10               Amazonas
# 11               Amazonas
# 12               Amazonas
# 13               Amazonas
# 14               Amazonas
# 15               Amazonas
# 16              Andalucía
# 17                 Aragón
# 18                 Aragón
# 19                 Aragón
# 20                 Aragón
# 21                  Bahia
# 22                  Bahia
# 23                  Bahia
# 24                  Bahia
# 25                  Bahia
# 26                  Bahia
# 27               Canarias
# 28               Cataluña
# 29                  Ceará
# 30                  Ceará
# 31                  Ceará
# 32                  Ceará
# 33   Comunidad Valenciana
# 34    Comunidad de Madrid
# 35    Comunidad de Madrid
# 36    Comunidad de Madrid
# 37    Comunidad de Madrid
# 38               Delaware
# 39       Distrito Federal
# 40       Distrito Federal
# 41       Distrito Federal
# 42                Florida
# 43                Florida
# 44                Florida
# 45                Florida
# 46                Florida
# 47                Florida
# 48                Florida
# 49                Florida
# 50                Florida
# 51                Galicia
# 52                Georgia
# 53                Georgia
# 54                Georgia
# 55                Georgia
# 56                Georgia
# 57                Georgia
# 58                 Shanxi
# 59                  Goiás
# 60                  Goiás
# 61       Gyeongsangnam-do
# 62       Gyeongsangnam-do
# 63       Gyeongsangnam-do
# 64       Gyeongsangnam-do
# 65       Gyeongsangnam-do
# 66       Gyeongsangnam-do
# 67       Gyeongsangnam-do
# 68       Gyeongsangnam-do
# 69       Gyeongsangnam-do
# 70       Gyeongsangnam-do
# 71       Gyeongsangnam-do
# 72       Gyeongsangnam-do
# 73       Gyeongsangnam-do
# 74       Gyeongsangnam-do
# 75       Gyeongsangnam-do
# 76       Gyeongsangnam-do
# 77              Louisiana
# 78               Maranhão
# 79               Maranhão
# 80               Maranhão
# 81               Maranhão
# 82               Maranhão
# 83               Maranhão
# 84               Maranhão
# 85               Maranhão
# 86            Mato Grosso
# 87               Michigan
# 88           Minas Gerais
# 89             New Mexico
# 90               New York
# 91    Nordrhein-Westfalen
# 92         North Carolina
# 93                 Paraná
# 94                   Pará
# 95                   Pará
# 96                   Pará
# 97                   Pará
# 98                   Pará
# 99                   Pará
# 100                  Pará
# 101                  Pará
# 102                  Pará
# 103                  Pará
# 104                  Pará
# 105                  Pará
# 106          Pennsylvania
# 107          Pennsylvania
# 108            Pernambuco
# 109            Pernambuco
# 110            Pernambuco
# 111            Pernambuco
# 112            Pernambuco
# 113      Región de Murcia
# 114              Rondônia
# 115              Rondônia
# 116                 Texas
# 117                 Texas
# 118                 Texas
# 119              Virginia
# 120              Virginia
# 121              Virginia
# 122              Virginia
# 123              Virginia
# 124              Virginia
# 125              Virginia
# 126              Virginia
# 127              Virginia
# 128              Virginia
# 129            Washington

# %%
#df_final creation by merging df with df_lookup 
df_final = df.merge(
    df_lookup[['postal_code', 'city']],
    on='postal_code',
    how='left',
    suffixes=('', '_lookup')
)

df_final['city'] = df_final['city'].fillna(df_final['city_lookup'])

df_final = df_final.drop(columns=['city_lookup'])

# %%
print(df_final[['postal_code', 'city', 'country', 'state']].head(60))
# Out:
#    postal_code               city country  state
# 0    69980-000    Cruzeiro do Sul  Brasil   Acre
# 1    69980-000    Cruzeiro do Sul  Brasil   Acre
# 2    69980-000    Cruzeiro do Sul  Brasil   Acre
# 3    69980-000    Cruzeiro do Sul  Brasil   Acre
# 4    69980-000    Cruzeiro do Sul  Brasil   Acre
# 5    69980-000    Cruzeiro do Sul  Brasil   Acre
# 6    69980-000    Cruzeiro do Sul  Brasil   Acre
# 7    69980-000    Cruzeiro do Sul  Brasil   Acre
# 8    69980-000    Cruzeiro do Sul  Brasil   Acre
# 9    69980-000    Cruzeiro do Sul  Brasil   Acre
# 10   69980-000    Cruzeiro do Sul  Brasil   Acre
# 11   69970-000           Tarauacá  Brasil   Acre
# 12   69970-000           Tarauacá  Brasil   Acre
# 13   69970-000           Tarauacá  Brasil   Acre
# 14   69970-000           Tarauacá  Brasil   Acre
# 15   69970-000           Tarauacá  Brasil   Acre
# 16   69970-000           Tarauacá  Brasil   Acre
# 17   69970-000           Tarauacá  Brasil   Acre
# 18   69970-000           Tarauacá  Brasil   Acre
# 19   69970-000           Tarauacá  Brasil   Acre
# 20   69940-000     Sena Madureira  Brasil   Acre
# 21   69940-000     Sena Madureira  Brasil   Acre
# 22   69940-000     Sena Madureira  Brasil   Acre
# 23   69940-000     Sena Madureira  Brasil   Acre
# 24   69940-000     Sena Madureira  Brasil   Acre
# 25   69917-400         Rio Branco  Brasil   Acre
# 26   69917-400         Rio Branco  Brasil   Acre
# 27   69917-400         Rio Branco  Brasil   Acre
# 28   69917-400         Rio Branco  Brasil   Acre
# 29   69917-400         Rio Branco  Brasil   Acre
# 30   69917-400         Rio Branco  Brasil   Acre
# 31   69917-400         Rio Branco  Brasil   Acre
# 32   69917-400         Rio Branco  Brasil   Acre
# 33   69917-400         Rio Branco  Brasil   Acre
# 34   69917-400         Rio Branco  Brasil   Acre
# 35   69917-400         Rio Branco  Brasil   Acre
# 36   69917-400         Rio Branco  Brasil   Acre
# 37   69917-400         Rio Branco  Brasil   Acre
# 38    494-0001    Ichinomiya City   Japan  Aichi
# 39    452-0961        Kiyosu City   Japan  Aichi
# 40    476-0015          Tokai-shi   Japan  Aichi
# 41    481-0004  North Nagoya City   Japan  Aichi
# 42    476-0005          Tokai-shi   Japan  Aichi
# 43    460-0008        Nagoya city   Japan  Aichi
# 44    476-0003          Tokai-shi   Japan  Aichi
# 45    476-0003          Tokai-shi   Japan  Aichi
# 46    476-0003          Tokai-shi   Japan  Aichi
# 47    476-0002          Tokai-shi   Japan  Aichi
# 48    460-0007        Nagoya city   Japan  Aichi
# 49    480-0102                  桑   Japan  Aichi
# 50    480-0102                  桑   Japan  Aichi
# 51    480-0102                  桑   Japan  Aichi
# 52    459-8001        Nagoya city   Japan  Aichi
# 53    459-8001        Nagoya city   Japan  Aichi
# 54    470-2102     Higashiura-cho   Japan  Aichi
# 55    470-2102     Higashiura-cho   Japan  Aichi
# 56    470-2102     Higashiura-cho   Japan  Aichi
# 57    470-2103     Higashiura-cho   Japan  Aichi
# 58    458-0801        Nagoya city   Japan  Aichi
# 59    458-0801        Nagoya city   Japan  Aichi

# %%
#puntual data error fetching and cleaning
df_final.loc[df_final['postal_code'] == '480-0102', 'city'] = ' Fusō'

# %%
#looking for missing values
missing_info4 = df_final[df_final['city'].isnull()]
print(missing_info4)
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, email, age, gender, state, street_address, postal_code, city, country, traffic_source, created_at, user_geom]
# Index: []

# %%
#save the final df to users_clean.csv
df_final.to_csv("users_cleaned2.csv", index=False)
